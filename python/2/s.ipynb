# %%
l1 = [1,2.5,3.1,4.25,"amit",'learing', True,[1,2,3],'False',['dl','ml','ds']]
l2 = [61,43,35,23.21,14,25]
print(l1)
print(l1 + l2)

l1 = [61,43,35,23,21,14,25]
print(l1)
l1.remove(43)
print(l1)
l1.pop()
print(l1)
# Out:
# [1, 2.5, 3.1, 4.25, 'amit', 'learing', True, [1, 2, 3], 'False', ['dl', 'ml', 'ds']]
# [1, 2.5, 3.1, 4.25, 'amit', 'learing', True, [1, 2, 3], 'False', ['dl', 'ml', 'ds'], 61, 43, 35, 23.21, 14, 25]
# [61, 43, 35, 23, 21, 14, 25]
# [61, 35, 23, 21, 14, 25]
# [61, 35, 23, 21, 14]

# %%
n = input('enter name')
id = input('enter id')
print(n,id)

l = ['amit', 'learing' , 'python']
x ='1'
x =input()
l.remove(x)
print(l)
# Out:
# amit amit
# ['learing', 'python']

# %%
d = {'k1':5,'k2':24,'k3':53}
print(d)
print(d['k1'])
# Out:
# {'k1': 5, 'k2': 24, 'k3': 53}
# 5

# %%
x1=int(input())
x2=int(input())
numadd  = x1+x2
numsub  = x1-x2
nummult = x1*x2
numdiv  = x1//x2
print (numadd,numsub,nummult,numdiv)
# Out:
# 15 5 50 2.0

# %%
x= int(input())
if 100<x or x<0 :{print('out')}
elif 100>x>90   :{print('A')}
elif 90>x>80    :{print('B')}
elif 80>x>70    :{print('C')}
elif 70>x>60    :{print('D')}
else    :{print('F')}
# Out:
# F
