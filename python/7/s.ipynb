# %%
import numpy as np
xx =np.array([[4, 10, 18],
            [2, 5, 2]])
def resize():
    r = int(input())
    c = int(input())
    print(xx.reshape(r, c))
resize()
# Out:
# [[ 4 10]
#  [18  2]
#  [ 5  2]]

# %%
x = np.array([[1, 2, 3,4, 5, 6]])
print(np.any(x > 1))
print(np.all(x > 1))
print(np.where(x > 3, -1, x))
# Out:
# True
# False
# [[ 1  2  3 -1 -1 -1]]
