# %%
#Task-1
#1
x = 'Amit_ml@gmail.edu'
x1 = (x.count("@"))
x2 = (x.count("."))
y1 = (x.index('@'))
y2 = (x.index('.'))
#print (x1,x2,y1,y2)
if x1 !=1 or x2<1 or y1>y2 :{print ("Invalid email0")}
#2
print (x[0:7])
#3
print (x[y1+1:y2])
#4
if x.count('.com')==1:{print('Commercial Domain')}
elif x.count('.edu')==1:{print('Educational Domain')}
else :{print("Other Domain")}
# Out:
# Amit_ml
# gmail
# Educational Domain

# %%
#Task-2
#1
x ='###!!@mocleW EPGTQ!!!6789'
xx=x[x.index('m'):x.index('!!!')]
print (xx)
#2
y = (xx.split()[0][::-1])
print (y)
#3
z = (xx.split()[1])
z1=z.replace("E","",)
print (z1)
#4
print (y+' '+z1)
# Out:
# mocleW EPGTQ
# Welcom
# PGTQ
# Welcom PGTQ

# %%
#Task-3
#1
x ='&&&**$gnirtS PLIO!!@1234'
xx=x[x.index('g'):x.index('!')]
print (xx)
#2
y = (xx.split()[0][::-1])
print (y)
#3
z = (xx.split()[1])
z1=z.replace("I","E",)
z2=z1.replace("O","U",)
print (z2)
#4
print (y+' '+z2)
# Out:
# gnirtS PLIO
# String
# PLEU
# String PLEU

# %%
#Task-4
#1
x ='##$$$@!yalpstcejorp EPUVT****9887'
xx=x[x.index('y'):x.index('*')]
print (xx)
#2
y = (xx.split()[0][::-1])
print (y)
#3
z = (xx.split()[1])
z1=z.replace("E","A",)
z2=z1.replace("U","O",)
print (z2)
#4
print (y+' '+z2)
# Out:
# yalpstcejorp EPUVT
# projectsplay
# APOVT
# projectsplay APOVT
