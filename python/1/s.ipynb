# %%
print ('my name is {0}, my age is {1}'.format('mohamed', 20))
print ('my name is {}, my age is {}'.format('mohamed', 20))
print ('my name is {x}, my age is {y}'.format(x='mohamed',y= 20))
# Out:
# my name is mohamed, my age is 20
# my name is mohamed, my age is 20
# my name is mohamed, my age is 20

# %%
print ('my name is {}, and I am {} years old,I am engaged in learning {}'.format('mohamed', 20,"machine learning"))
# Out:
# my name is mohamed, and I am 20 years old,I am engaged in learning machine learning

# %%
n = 'amit learing'
print (n[5:12])
# Out:
# learing
