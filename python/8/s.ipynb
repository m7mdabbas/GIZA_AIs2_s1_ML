# %%
import pandas as pd
data = [[1,123,'a'],
        [2,456,'b'],
        [3,789,'c']
]
data = pd.DataFrame(data, columns=['id','value','category'])
print(data)
data.index = data['id']
print(data)
data['value'].dtype
data['category'].unique()
# Out:
#    id  value category
# 0   1    123        a
# 1   2    456        b
# 2   3    789        c
#     id  value category
# id
# 1    1    123        a
# 2    2    456        b
# 3    3    789        c
# array(['a', 'b', 'c'], dtype=object)
