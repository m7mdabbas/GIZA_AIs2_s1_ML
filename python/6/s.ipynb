# %%
import numpy as np
x1 = np.array([1, 2, 3])
x2 = np.array([4, 5, 6])
print(x1 * x2)
x1.shape
# Out:
# [ 4 10 18]
# (3,)

# %%
y=np.array([[4, 10, 18],
            [2, 5, True]])
print(y.dtype)
print(y[1, 2])

y=np.array([[4, 10, 18],
            [2, 5, 'True']])
print(y.dtype)
print(y[1, 2])

def c():
    pass
c1=c()
y=np.array([[4, 10, 18],
            [2, 5, c1]])
print(y.dtype)
print(y[1, 2])
# object - string - float - int - bool
# Out:
# int64
# 1
# <U21
# True
# object
# None

# %%
x = np.array([1, 2, 3])
x.reshape(3, 1)
# Out:
# array([[1],
#        [2],
#        [3]])
